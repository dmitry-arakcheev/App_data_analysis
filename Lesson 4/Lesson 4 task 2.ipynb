# %% [markdown]
# # Задание

# %% [markdown]
# **Маркетологи запустили массивную рекламную кампанию, в результате в приложение пришло довольно много новых пользователей, вы можете видеть всплеск на графике активной аудитории.
# Однако у нас есть сомнение в качестве трафика.
# Изучите, что стало с рекламными пользователями в дальнейшем, как часто они продолжают пользоваться приложением?**

# %% [markdown]
# *вместо ссылки на дашборд здесь будет приведено изображение*

# %% [markdown]
# ![Анализ рекламной кампании](Dashboard_5/анализ-продуктовых-метрик-рекламная-кампания.jpg "Приток новых пользователей")

# %% [markdown]
# ![Анализ рекламной кампании](Dashboard_5/dau.jpg "DAU")

# %% [markdown]
# ![Анализ рекламной кампании](Dashboard_5/retention-для-рекламной-кампании-13-02-2023.jpg "Retention для рекламной кампании 13.02.23")

# %% [markdown]
# ![Анализ рекламной кампании](Dashboard_5/retention-для-рекламной-кампании-13-02-2023-2-соседних-дня-1.jpg "Retention для рекламной кампании 13.02.23 и двух соседних дней")

# %% [markdown]
# ![Анализ рекламной кампании](Dashboard_5/retention-для-рекламной-кампании-13-02-2023-2-соседних-дня-2.jpg "Retention для рекламной кампании 13.02.23 и двух соседних дней (%)")

# %% [markdown]
# ### Вывод
# **Резкий приток новых пользователей 13.02.2023 на графике отражает результат рекламной кампании. Однако, анализ данных пользователей показывает экстремально низкий Retention. Retention второго дня для пользователей, привлеченных по рекламным каналам, как правило составляет от 20 до 45% аудитории. Для пользователей, пришедших в результате рекламной кампании 13.02.2023, retention второго дня составил менее 3%, а к концу четвертой недели составил менее 1%.**
